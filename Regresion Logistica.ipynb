# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("C:/dataset/framingham2.csv", sep=",")

# %%
data
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
data[['BMI','BPMeds']].head()
# Out:
#      BMI  BPMeds
# 0  26.97     0.0
# 1  28.73     0.0
# 2  25.34     0.0
# 3  28.58     0.0
# 4  23.10     0.0

# %%
data[['BMI','BPMeds']].plot.scatter(x='BMI',y='BPMeds')
# Out:
# <Axes: xlabel='BMI', ylabel='BPMeds'>

# %%
# pruebas de parametro
w = 0.09
b = -3.6

# %%
x = np.linspace(0,data['BMI'].max(),100)
y = 1/(1+np.exp(-(w*x+b)))

# %%
data.plot.scatter(x='BMI',y='BPMeds')
plt.plot(x, y, color='black')
plt.ylim(0,data['BPMeds'].max()*1.1)
plt.scatter(x, y, color='#A9E2F3')
# plt.grid()
plt.xlabel('Indice de Masa Corporal')
plt.ylabel('BPMeds')
plt.show()
